# %% [markdown]
# # PINN como funcion que satisfaga la Ec. de Burger
# ---
# Una PINN no aprende datos. Aprende una función que hace que el residual de la ecuación diferencial sea cercano a cero.
#
# Supón que una PINN propone:
# $ u_θ(x,t) $
#
# Entonces calculamos:
# -  $ u_t$
# - $ u_x $
# - $ u_xx $
# 	​
# y sustituimos :
